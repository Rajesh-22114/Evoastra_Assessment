# %% [markdown]
# # Evoastra Ventures Intern Assessment Task
# **Duration: 35 Minutes | Total Points: 100**
#
# ---

# %% [markdown]
# ## **Candidate Information**
#
# **Fill in your details below:**
# - **Name:** KOMMU RAJESH
# - **Email:** rajeshricky501@gmail.com
# - **Phone:** 9603448511
# - **College/University:** Acharya Nagarjuna University
# - **Course/Branch:** AIML
# - **Start Time:** 12:39 pm
# - **End Time:** 1:25 pm

# %% [markdown]
# ## **Dataset for Assessment**
#
# **E-commerce Customer Behavior Dataset**
# - **Direct Link:** https://www.kaggle.com/datasets/shriyashjagtap/e-commerce-customer-for-behavior-analysis
#
# **Dataset Columns:**
# - **Customer ID:** Unique identifier for each customer
# - **Customer Name:** Name of the customer
# - **Customer Age:** Age of the customer
# - **Gender:** Gender of the customer
# - **Purchase Date:** Date of each purchase
# - **Product Category:** Category of the purchased product
# - **Product Price:** Price of the purchased product
# - **Quantity:** Quantity of product purchased
# - **Total Purchase Amount:** Total amount spent in each transaction
# - **Payment Method:** Payment method used (credit card, PayPal, etc.)
# - **Returns:** Whether customer returned products (0 = No, 1 = Yes)
# - **Churn:** Whether customer has churned (0 = Retained, 1 = Churned)

# %% [markdown]
# ---
# ## **SECTION A: Data Understanding & Basic Analysis (25 Points - 10 Minutes)**

# %% [markdown]
# ### Question 1 (8 points)
# Based on the dataset structure, identify the **data types** for the following columns and explain why each classification is important for analysis:
#
# - **Customer Age**
# - **Gender**
# - **Total Purchase Amount**
# - **Churn**

# %%
# Your Answer for Question 1
# Customer Age: Customer Age column is int data type, it will helps to identify the age groups that buy more products

# Gender: it is categorical data type, it will helps in targeted marketing. Like if the one gender is buying more products and another gender buying less products then we should understand that we have to improve the products that helps for the people belongs to that specified gender

# Total Purchase Amount:it is also int data type, it helps us to measure the customer value

# Churn:it is binary data type, it helps us to identify the customers who are churning and by that we can identify the reasons they are Churning

# %% [markdown]
# ### Question 2 (8 points)
# Which **analytical technique** would be most appropriate for each business question below?
#
# a) "Which product categories generate the highest revenue?"
# b) "Can we predict customer churn based on purchase behavior?"
# c) "What is the relationship between customer age and spending patterns?"
# d) "Which payment methods are preferred by different customer segments?"

# %%
# Your Answer for Question 2
# a) Product categories with highest revenue:we can find it by using Descriptive analytics that means sum the revenue by category.

# b) Predicting customer churn:we can predict this by developing a classification model.

# c) Age and spending relationship:we can measure the relationship between the age and spending by using correlation or Regression methods

# d) Payment method preferences:by using segmentation analysis this will helps us to analyse the groups of customers based on the characteristics like age , spending. .etc

# %% [markdown]
# ### Question 3 (9 points)
# **Data Quality Assessment:** What are the top 3 potential data quality issues you would check for in this e-commerce dataset before starting analysis? For each issue, suggest one method to detect it.

# %%
# Your Answer for Question 3
# Issue 1:to check the null values on the data set.

# Detection Method 1:uses .isnull().sum() this will shows us the how many null values are there in our dataset

# Issue 2:wrong formats like "male","m", " female","f'

# Detection Method 2:first we have to convert all those to lower case by '''df['gender'] = df['gender'].str.lower()''' and then we can replace all male into m and female into f by ''' df['gender'] = df['gender'].replace({"male":"m","female":"f"})

# Issue 3:and to identify the duplicates

# Detection Method 3:by .duplicated().sum() this will shows the no of duplicates

# %% [markdown]
# ---
# ## **SECTION B: Customer Analysis & Business Intelligence (35 Points - 15 Minutes)**

# %% [markdown]
# ### Scenario: E-commerce Revenue Analysis
#
# Based on the dataset structure, assume you have the following customer insights:
#
# **Customer Segments by Age:**
# - **Young (18-30):** 40% of customers, Average Purchase Amount: ₹850, Return Rate: 12%
# - **Middle-aged (31-50):** 45% of customers, Average Purchase Amount: ₹1,200, Return Rate: 8%
# - **Senior (51+):** 15% of customers, Average Purchase Amount: ₹950, Return Rate: 15%
#
# **Additional Information:**
# - Average customer acquisition cost: ₹180
# - Platform profit margin: 20% of purchase amount
# - Customer churn rates: Young (25%), Middle-aged (15%), Senior (30%)

# %% [markdown]
# ### Question 4 (15 points)
# **Calculate and analyze:**
#
# a) Which customer segment generates the highest **net profit per customer** (considering returns)? Show your calculations. (8 points)
#
# b) Which segment has the **best customer lifetime value** considering churn rates? Provide reasoning. (7 points)

# %%
# Your Calculations for Question 4

# a) Net profit per customer calculations:

# Young Customers:
''' Avg Purchase = ₹850 ,Return Rate = 12% = 0.12
Effective Amount = 850 × (1 – 0.12) = 850 × 0.88 = ₹748
Profit = 748 × 0.20 = ₹149.6
Net Profit = 149.6 – 180 = –₹30.4 (loss) '''

# Middle-aged Customers:
''' Avg Purchase = ₹1200 ,Return Rate = 8% = 0.08
Effective Amount = 1200 × (1 – 0.08) = 1200 × 0.92 = ₹1104
Profit = 1104 × 0.20 = ₹220.8
Net Profit = 220.8 – 180 = ₹40.8 (profit) '''

# Senior Customers:
''' Avg Purchase = ₹950 ,Return Rate = 15% = 0.15
Effective Amount = 950 × (1 – 0.15) = 950 × 0.85 = ₹807.5
Profit = 807.5 × 0.20 = ₹161.5
Net Profit = 161.5 – 180 = –₹18.5 (loss) '''
# b) Customer Lifetime Value Analysis:
'''CLV rule is :Lower churn rate = higher customer lifetime value.
After comparisons Middle-aged customers have the highest CLV because they have the lowest churn rate (15%) and also produced the highest net profit per customer.'''
# Out:
# 'CLV rule is :Lower churn rate = higher customer lifetime value.\nAfter comparisons Middle-aged customers have the highest CLV because they have the lowest churn rate (15%) and also produced the highest net profit per customer.'

# %% [markdown]
# ### Question 5 (10 points)
# **Strategic Recommendations:** Based on your analysis, what would be your **top 2 marketing strategies** to maximize overall profitability? Consider customer acquisition, retention, and return rates.

# %%
# Your Answer for Question 5

# Strategy 1:Reduce Return Rates
''' Improve product descriptions, sizing guides, and quality checks to lower return rates—this directly increases net profit, especially for Young and Senior segments who have higher return percentages.'''

# Strategy 2:Strengthen Retention for Middle-Aged Customers
''' Since the middle-aged segment has the highest net profit and best CLV, offer targeted loyalty rewards, personalized recommendations, and exclusive discounts to retain them and maximize long-term revenue.'''
# Out:
# ' Since the middle-aged segment has the highest net profit and best CLV, offer targeted loyalty rewards, personalized recommendations, and exclusive discounts to retain them and maximize long-term revenue.'

# %% [markdown]
# ### Question 6 (10 points)
# **Churn Prevention:** You notice that customers who make purchases in the "Electronics" category have a 35% churn rate, while "Fashion" category customers have only 18% churn rate. What **specific data analysis** would you conduct using the available dataset columns to understand this difference, and what **action plan** would you recommend?

# %%
# Your Answer for Question 6

# Data Analysis Plan:Compare Electronics vs Fashion customers on return rates, purchase amount, frequency, and payment methods using segmentation and churn correlation analysis.

# Action Plan:Improve Electronics category experience by enhancing product quality, clearer descriptions, faster support, and offering warranties to reduce dissatisfaction and churn.

# %% [markdown]
# ---
# ## **SECTION C: Research Methodology & Predictive Analytics (25 Points - 8 Minutes)**

# %% [markdown]
# ### Scenario: Churn Prediction Model Development
#
# Your company wants to build a machine learning model to predict customer churn using the available dataset.

# %% [markdown]
# ### Question 7 (15 points)
# **Model Development Plan:** Create a comprehensive approach including:
#
# a) **Feature selection:** Which columns from the dataset would you use as features for the churn prediction model and why? (5 points)
# b) **Data preprocessing steps:** What preprocessing would you apply to prepare the data? (5 points)
# c) **Model evaluation metrics:** Which metrics would you use to evaluate model performance for this business problem? (5 points)

# %%
# Your Answer for Question 7

# a) Feature Selection:Use features like age, gender, product category, purchase amount, quantity, payment method, returns, and purchase frequency because these directly influence customer behavior and churn.

# b) Data Preprocessing Steps:Clean missing values, encode categorical columns, normalize numerical features, remove duplicates, and split the dataset into training and testing sets.

# c) Model Evaluation Metrics:Use accuracy for overall performance, precision/recall for churn identification quality, and ROC-AUC to measure model discrimination.

# %% [markdown]
# ### Question 8 (10 points)
# **Business Impact Analysis:** Identify 3 potential business challenges in implementing a churn prediction model and propose one **data-driven solution** for each challenge using insights from the customer behavior dataset.

# %%
# Your Answer for Question 8

# Challenge 1:Churn data may be imbalanced, making the model biased.
# Data-driven Solution 1:Use oversampling (SMOTE) or class weighting to balance churn vs non-churn customers.

# Challenge 2:Customer data may contain missing, inconsistent, or noisy values.
# Data-driven Solution 2:Apply data cleaning, validation checks, and proper preprocessing to improve model accuracy.

# Challenge 3:Customer behavior changes over time, reducing model performance.
# Data-driven Solution 3:Retrain the model regularly using updated customer behavior and purchase data.

# %% [markdown]
# ---
# ## **SECTION D: Professional Communication & Problem-Solving (15 Points - 2 Minutes)**

# %% [markdown]
# ### Question 9 (8 points)
# **Crisis Management:** While analyzing the dataset, you discover that 40% of customers who returned products (Returns = 1) also churned within the same month. However, your initial analysis showed returns don't strongly correlate with churn. As a team member, describe your immediate approach to investigate this discrepancy and communicate findings to stakeholders (60-80 words).

# %%
# Your Answer for Question 9 (60-80 words)
''' I would first recheck the data filters, time period, and calculation steps to confirm whether the churn-return relationship was analyzed correctly. Then I would run a focused comparison of customers who returned products to verify if churn occurred in the same month. After validating the results, I would prepare a brief summary explaining the discrepancy and communicate the corrected insight clearly to stakeholders, along with recommended next steps '''
# Out:
# ' I would first recheck the data filters, time period, and calculation steps to confirm whether the churn-return relationship was analyzed correctly. Then I would run a focused comparison of customers who returned products to verify if churn occurred in the same month. After validating the results, I would prepare a brief summary explaining the discrepancy and communicate the corrected insight clearly to stakeholders, along with recommended next steps '

# %% [markdown]
# ### Question 10 (7 points)
# **Leadership Scenario:** If selected as team lead for analyzing this e-commerce customer dataset, what would be your **top 3 priorities** to ensure effective team collaboration and delivery of actionable business insights?

# %%
# Your Answer for Question 10

# Priority 1:ensure clear task assignment

# Priority 2:maintain strong data quality

# Priority 3:create simple,actionable reports

# %% [markdown]
# ---
# ## **Self-Assessment Section**

# %%
# Time Management Check
# Did you complete all sections within 35 minutes? (Yes/No):No

# Which section took the most time? : i think section B

# Which section was most challenging? : i think its section C

# Confidence Level (1-10 scale):
# Section A (Data Understanding):9
# Section B (Business Analysis):8
# Section C (Research Methodology):6
# Section D (Communication):7

# Additional Comments:

# %% [markdown]
# ---
# ## **Submission Instructions**
#
# 1. **Save this notebook** with the filename: `YourName_Evoastra_Assessment.ipynb`
# 2. **Ensure all code cells have been executed** and answers are visible
# 3. **Double-check** that all sections are completed
#
# **Submission Confirmation:**
# - I confirm that I have completed this assessment independently
# - All my responses are my own original work
#
# **Digital Signature:** _K Rajesh_______________________
# **Final Submission Time:** _2:10___________________

# %% [markdown]
# ---
# ## **Evaluation Criteria**
#
# **Scoring Breakdown:**
# - **Section A (Data Understanding):** 25 points
# - **Section B (Business Analysis):** 35 points
# - **Section C (Research Methodology):** 25 points
# - **Section D (Communication):** 15 points
# - **Total:** 100 points
#
# **Team Selection Criteria:**
# - **Team Lead:** Score ≥ 75 points + Strong Section D performance
# - **Co-Lead:** Score ≥ 65 points + Good Section D performance
# - **Team Member:** Successful completion of assessment
#
# ---
#
# *Good luck with your assessment! Focus on clear reasoning, accurate calculations, and practical business applications.*
